# %%
import platform
import sys
import torch

print(f"OS Platform: {platform.platform()}")
print(f"Python Version: {sys.version.split()[0]}")
print(f"PyTorch Version: {torch.__version__}")

# Apple Silicon GPU check (Metal Performance Shaders)
mps_available = (
    hasattr(torch.backends, "mps") and torch.backends.mps.is_available()
)
print(f"Apple Silicon MPS (GPU) Available: {mps_available}")
å
# NVIDIA CUDA GPU check
cuda_available = torch.cuda.is_available()
print(f"NVIDIA CUDA Available: {cuda_available}")
# Out:
# Running cells with 'Python 3.12.14' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'
